# %%
import pandas as pd

# %%
df = pd.read_csv('riber.csv')

# %%
df
# Out:
#                         created_at                   id               id_str  \
# 0   Fri Jul 03 17:25:23 +0000 2020  1279103959114944512  1279103959114944512
# 1   Fri Jul 03 17:21:21 +0000 2020  1279102944802156548  1279102944802156548
# 2   Fri Jul 03 17:20:44 +0000 2020  1279102792217563139  1279102792217563139
# 3   Fri Jul 03 17:15:53 +0000 2020  1279101570219675648  1279101570219675648
# 4   Fri Jul 03 17:13:18 +0000 2020  1279100918345150464  1279100918345150464
# ..                             ...                  ...                  ...
# 95  Fri Jul 03 13:17:22 +0000 2020  1279041545849749504  1279041545849749504
# 96  Fri Jul 03 13:13:11 +0000 2020  1279040492504862720  1279040492504862720
# 97  Fri Jul 03 13:07:56 +0000 2020  1279039171844341762  1279039171844341762
# 98  Fri Jul 03 13:06:49 +0000 2020  1279038891798953986  1279038891798953986
# 99  Fri Jul 03 12:54:05 +0000 2020  1279035684683239429  1279035684683239429
#
# ...

# %%
condition = df['retweeted_status'].isna()

# %%
df[~condition]['full_text'] =df[~condition]['retweeted_status']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-9b278cd8a4fb> in <module>
# ----> 1 df[~condition]['full_text'] =df[~condition]['retweeted_status']['full_text']
#
# /opt/anaconda3/envs/Ironhack/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# /opt/anaconda3/envs/Ironhack/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
# ...

# %%
df[~condition].retweeted_status[4]
# Out:
# '{\'created_at\': \'Fri Jul 03 16:49:59 +0000 2020\', \'id\': 1279095051746975746, \'id_str\': \'1279095051746975746\', \'full_text\': \'@pabloferra @Xeneixe_se_nace @drflagelo @diego_villalba8 Hay que declararlos personas no gratas. \\nPor anti boca .por sobreros.mala leche.\\nQue de pueden esperar todos periodistas de equipos descendidos allboys.riber racing.indepengiente San Lorenzo..\\nBeltramo. Y leto lis único que ponen el pecho por boca\', \'truncated\': False, \'display_text_range\': [57, 304], \'entities\': {\'hashtags\': [], \'symbols\': [], \'user_mentions\': [{\'screen_name\': \'pabloferra\', \'name\': \'C.A.B.J\', \'id\': 151488236, \'id_str\': \'151488236\', \'indices\': [0, 11]}, {\'screen_name\': \'Xeneixe_se_nace\', \'name\': \'Sanjo\', \'id\': 3371187351, \'id_str\': \'3371187351\', \'indices\': [12, 28]}, {\'screen_name\': \'drflagelo\', \'name\': \'Dr. Flagelo\', \'id\': 2442279284, \'id_str\': \'2442279284\', \'indices\': [29, 39]}, {\'screen_name\': \'diego_vill
# ...
